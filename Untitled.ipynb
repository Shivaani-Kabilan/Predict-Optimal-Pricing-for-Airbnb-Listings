# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('listings.csv')
data
# Out:
#              id                            listing_url       scrape_id  \
# 0        183319    https://www.airbnb.com/rooms/183319  20220909140055
# 1         51307     https://www.airbnb.com/rooms/51307  20220909140055
# 2        184314    https://www.airbnb.com/rooms/184314  20220909140055
# 3         51498     https://www.airbnb.com/rooms/51498  20220909140055
# 4           109       https://www.airbnb.com/rooms/109  20220909140055
# ...         ...                                    ...             ...
# 45810  26665862  https://www.airbnb.com/rooms/26665862  20220909140055
# 45811  26898605  https://www.airbnb.com/rooms/26898605  20220909140055
# 45812  26895703  https://www.airbnb.com/rooms/26895703  20220909140055
# 45813  26954426  https://www.airbnb.com/rooms/26954426  20220909140055
# 45814  27901174  https://www.airbnb.com/rooms/27901174  20220909140055
#
#       last_scraped           source  \
# 0       2022-09-10  previous scrape
# 1       2022-09-10      city scrape
# ...

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
data = data.drop(['id', 'listing_url',  'scrape_id', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id',
       'host_url', 'host_name', 'host_since', 'host_location', 'host_about','host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood','host_verifications','host_has_profile_pic', 'host_identity_verified',],axis = 1)

# %%
data.isna().sum()
# Out:
# host_response_time                               8880
# host_response_rate                               8880
# host_acceptance_rate                             7968
# host_is_superhost                                  98
# host_listings_count                                13
# host_total_listings_count                          13
# neighbourhood                                   19063
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                     7889
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                       45815
# bathrooms_text                                     71
# bedrooms                                         3760
# ...

# %%
data = data.dropna(axis = 1)
data.price = data.price.map(lambda x: float(x[1::].replace(',','')))
data
# Out:
#       neighbourhood_cleansed  latitude  longitude              property_type  \
# 0                     Venice  33.99211 -118.47600         Entire rental unit
# 1            Atwater Village  34.12206 -118.26783            Entire bungalow
# 2                     Venice  33.97487 -118.46312         Entire rental unit
# 3                  Mar Vista  34.00389 -118.44126          Entire guesthouse
# 4                Culver City  33.98301 -118.38607               Entire condo
# ...                      ...       ...        ...                        ...
# 45810             Costa Mesa  33.65904 -117.93169       Private room in home
# 45811             Costa Mesa  33.68059 -117.88340         Entire rental unit
# 45812                Anaheim  33.83284 -117.94672  Entire serviced apartment
# 45813           Agoura Hills  34.17577 -118.75948               Entire villa
# 45814             Costa Mesa  33.67880 -117.88515         Entire rental unit
#
#              room_type  accommodates  \
# ...

# %%
sns.pairplot(data)

# %%
for x in data.price.values:
    print(x)
# Out:
# 152.0
# 75.0
# 125.0
# 189.0
# 115.0
# 85.0
# 93.0
# 100.0
# 85.0
# 179.0
# 350.0
# 50.0
# 87.0
# 165.0
# 60.0
# 120.0
# 85.0
# 50.0
# 65.0
# 59.0
# 147.0
# 89.0
# 109.0
# 135.0
# 71.0
# 417.0
# 140.0
# 100.0
# 138.0
# 150.0
# 80.0
# 105.0
# 300.0
# 115.0
# 45.0
# 140.0
# 340.0
# 500.0
# 901.0
# 80.0
# 85.0
# 99.0
# 74.0
# 99.0
# 185.0
# 109.0
# 119.0
# 180.0
# 65.0
# 363.0
# 185.0
# 150.0
# 185.0
# 140.0
# 150.0
# 204.0
# 120.0
# 504.0
# 168.0
# 400.0
# 110.0
# 119.0
# 99.0
# 257.0
# 68.0
# 75.0
# 75.0
# 224.0
# 191.0
# 329.0
# 129.0
# 62.0
# 286.0
# 115.0
# 899.0
# 83.0
# 272.0
# 30.0
# 154.0
# 210.0
# 297.0
# 125.0
# 99.0
# 93.0
# 263.0
# 130.0
# 139.0
# 185.0
# 120.0
# 105.0
# 699.0
# 59.0
# 95.0
# 375.0
# 1499.0
# 150.0
# 89.0
# 396.0
# 550.0
# 128.0
# 200.0
# 319.0
# 66.0
# 75.0
# 245.0
# 277.0
# 150.0
# 180.0
# 179.0
# 193.0
# 79.0
# 225.0
# 116.0
# 39.0
# 188.0
# 382.0
# 999.0
# 63.0
# 132.0
# 59.0
# 50.0
# 80.0
# 115.0
# 75.0
# 169.0
# 155.0
# 125.0
# 75.0
# 100.0
# 149.0
# ...

# %%
data.price
# Out:
# 0        152.0
# 1         75.0
# 2        125.0
# 3        189.0
# 4        115.0
#          ...
# 45810     60.0
# 45811    104.0
# 45812    134.0
# 45813    300.0
# 45814    105.0
# Name: price, Length: 45815, dtype: float64
